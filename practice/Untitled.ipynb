# %%
#import
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore') 

df = pd.read_csv('../assets/data/n_lang.csv')

df.sort_values(by=['언론사'], axis=0, inplace=True)

group_df = df.groupby(by='언론사')
df_save = group_df.count()
df_save
# Out:
#         뉴스 식별자  일자  기고자  제목  통합 분류1  ...  키워드  특성추출(가중치순 상위 50개)  본문  URL  분석제외 여부
# 언론사                                  ...
# 강원도민일보       1   1    1   1       1  ...    1                  1   1    1        0
# 경향신문         2   2    2   2       2  ...    2                  2   2    2        0
# 광주일보         1   1    1   1       1  ...    1                  1   1    1        0
# 국민일보         4   4    4   4       4  ...    4                  4   4    4        0
# 내일신문         3   3    3   3       3  ...    3                  3   3    3        0
# 동아일보        11  11    8  11      11  ...   11                 11  11   11        0
# 디지털타임스      29  29   29  29      29  ...   29                 29  29   29        0
# 매일경제        16  16   13  16      16  ...   16                 16  16   16        0
# 매일신문         1   1    1   1       1  ...    1                  1   1    1        0
# 머니투데이       28  28   28  28      28  ...   28                 28  28   28        0
# 문화일보         1   1    1   1       1  ...    1                  1   1    1        0
# 부산일보         7   7    7   7       7  ...    7                  7   7    7        0
# 서울경제        22  22   22  22      22  ...   22                 22  22   22        0
# 서울신문         2   2    2   2       2  ...    2                  2   2    2        0
# 세계일보        12  12   11  12      12  ...   12                 12  12   12        0
# 아시아경제       24  24   23  24      24  ...   24                 24  24   24        1
# 아주경제        42  42   42  42      42  ...   42                 42  42   42        0
# 영남일보         2   2    2   2       2  ...    2                  2   2    2        0
# 전남일보         1   1    1   1       1  ...    1                  1   1    1        0
# 전북도민일보       3   3    3   3       3  ...    3                  3   3    3        0
# 전북일보         1   1    1   1       1  ...    1                  1   1    1        0
# 전자신문        51  51   50  51      51  ...   51                 51  51   51        0
# 조선일보         2   2    2   2       2  ...    2                  2   2    2        0
# 중도일보         1   1    1   1       1  ...    1                  1   1    1        0
# 중부매일         1   1    1   1       1  ...    1                  1   1    1        0
# 중앙일보        10  10    7  10      10  ...   10                 10  10   10        0
# 충청투데이        1   1    1   1       1  ...    1                  1   1    1        0
# 파이낸셜뉴스       6   6    6   6       6  ...    6                  6   6    6        0
# 한겨레          2   2    2   2       2  ...    2                  2   2    2        0
# 한국경제        26  26   24  26      26  ...   26                 26  26   26        1
# 한국일보         2   2    2   2       2  ...    2                  2   2    2        0
# 헤럴드경제       18  18   18  18      18  ...   18                 18  18   18        1
#
# [32 rows x 18 columns]
